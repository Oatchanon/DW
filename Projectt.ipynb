# %% [markdown]
# <a href="https://colab.research.google.com/github/Oatchanon/DW/blob/master/Projectt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_train =pd.read_csv('https://raw.githubusercontent.com/plenoi/CMU_DataScience/master/DIPEP.csv' ,header=None)
df_train.head()
# Out:
#    0          1           2         3    ...       397       398       399  400
# 0    0  9999999.0  9999999.00 -1.000000  ... -0.754045 -1.000000 -0.718446 -1.0
# 1    0       -1.0       -1.00 -1.000000  ... -1.000000 -0.312254 -1.000000 -1.0
# 2    0       -1.0       -0.84 -0.820690  ... -1.000000 -1.000000 -1.000000 -1.0
# 3    0       -1.0       -1.00 -0.886152  ... -1.000000 -0.811075 -0.716612 -1.0
# 4    0       -1.0       -1.00 -0.774452  ... -0.496689 -1.000000 -1.000000 -1.0
#
# [5 rows x 401 columns]

# %%
df_train.shape
# Out:
# (3587, 401)

# %%
df_train.dtypes
# Out:
# 0        int64
# 1      float64
# 2      float64
# 3      float64
# 4      float64
#         ...
# 396    float64
# 397    float64
# 398    float64
# 399    float64
# 400    float64
# Length: 401, dtype: object

# %%
df_train.isnull().sum(axis=0)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 396    0
# 397    0
# 398    0
# 399    0
# 400    0
# Length: 401, dtype: int64

# %%
y=df_train.iloc[:,0]
X=df_train.iloc[:,1:401]

# %%
X.shape
# Out:
# (3587, 400)

# %%
y.shape
# Out:
# (3587,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
y_train
# Out:
# 3174    1
# 991     0
# 3102    1
# 2448    1
# 3199    1
#        ..
# 835     0
# 3264    1
# 1653    1
# 2607    1
# 2732    1
# Name: 0, Length: 2690, dtype: int64

# %%
y_val
# Out:
# 1907    1
# 1869    1
# 2719    1
# 2618    1
# 2229    1
#        ..
# 1555    1
# 3500    1
# 2963    1
# 666     0
# 2306    1
# Name: 0, Length: 897, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scl =MinMaxScaler()
scl.fit(X_train)0..
x_train_norm = scl.transform(X_train)
x_val_norm = scl.transform(X_val)

# %%
x_val_norm.max(axis=0)
# Out:
# array([9.01234800e-08, 6.46464000e-08, 8.87213500e-01,            nan,
#                   nan,            nan,            nan,            nan,
#        4.24417500e-01,            nan, 5.63492000e-01, 1.26421851e+00,
#        4.15206000e-01, 6.06837500e-01, 4.76190000e-01,            nan,
#        6.85071000e-01, 5.40440950e-01, 8.91567500e-01, 5.47826500e-01,
#        1.32631536e+00, 1.06779654e+00, 6.91861000e-01, 4.15584000e-01,
#        6.87117000e-01, 6.98113000e-01, 1.16279002e+00, 4.61021150e-01,
#        7.60328000e-01, 4.89411200e-01, 1.46376772e+00, 9.86112500e-01,
#        7.62034000e-01, 8.50793500e-01, 2.80855000e-01, 9.64101500e-01,
#        6.45160000e-01, 8.93081000e-01, 6.52630000e-01, 5.35714300e-01,
#        1.11304348e+00, 6.87072000e-01, 6.09465500e-01, 5.12456000e-01,
#        7.76179000e-01, 8.99973115e-01, 7.21393500e-01, 3.98898340e-01,
#        1.01746892e+00, 5.88707500e-01, 1.17829625e+00, 3.52941000e-01,
#        5.34798050e-01, 4.22535000e-01, 8.98549500e-01, 7.58063000e-01,
#        5.40440950e-01, 9.92002000e-01, 6.07845000e-01, 1.08024783e+00,
#        4.20420500e-01, 7.81818000e-01, 4.14966000e-01, 8.70936000e-01,
#        8.13954000e-01, 7.07866500e-01, 3.50877000e-01, 2.32558500e-01,
#        6.74795000e-01, 9.65516500e-01, 9.66667500e-01, 1.03571079e+00,
#        1.42045455e+00, 6.25779000e-01, 7.59492000e-01, 9.52379500e-01,
#        7.06732500e-01, 7.95920500e-01, 7.07070500e-01, 5.89625000e-01,
#        6.73077500e-01, 3.53535500e-01, 1.85487341e+00, 1.03686576e+00,
#        6.92308000e-01, 1.03365156e+00, 1.07092466e+00, 4.56140600e-01,
#        6.62575500e-01, 1.28149679e+00, 6.47999000e-01, 5.75344000e-01,
#        1.01325079e+00, 3.37350914e-01, 1.01801583e+00, 9.43753000e-01,
#        9.85665500e-01, 7.39132000e-01, 6.62554000e-01, 4.34782500e-01,
#        6.35134500e-01, 6.95342000e-01, 9.14528500e-01, 1.09523867e+00,
#        1.07647609e+00, 7.44603500e-01, 7.36606000e-01, 8.65386000e-01,
#        7.66665000e-01, 6.02271500e-01, 6.13333500e-01, 4.34782500e-01,
#        7.76471000e-01, 9.17647500e-01, 6.86274000e-01, 7.03541500e-01,
#        7.87876500e-01, 9.07895500e-01, 1.23529688e+00, 1.94594590e+00,
#        6.83615000e-01, 1.66666500e-01, 6.09137000e-01, 4.48000000e-01,
#        7.14285500e-01, 8.47290000e-01, 6.57276000e-01, 6.73684500e-01,
#        8.88887500e-01, 5.66667000e-01, 6.05504500e-01, 9.69827500e-01,
#        3.72972500e-01, 6.69456000e-01, 8.03030500e-01, 6.88071500e-01,
#        9.91937500e-01, 7.46479500e-01, 5.66372000e-01, 9.61167000e-01,
#        6.12665500e-01, 2.90521862e-01, 9.27916000e-01, 1.00226060e+00,
#        7.36110000e-01, 7.05000000e-01, 5.94772500e-01, 5.32544050e-01,
#        7.43852500e-01, 9.40000000e-01, 1.18491064e+00, 7.01491500e-01,
#        6.28744000e-01, 8.55555500e-01, 1.24584666e+00, 4.62546350e-01,
#        6.87286500e-01, 7.94114500e-01, 9.26228000e-01, 9.02779500e-01,
#        1.05785292e+00, 8.29270000e-01, 9.27270500e-01, 4.54147650e-01,
#        4.52736550e-01, 6.91666500e-01, 5.78431500e-01, 1.64864967e+00,
#        7.04000000e-01, 4.46427500e-01, 6.31884500e-01, 8.00000000e-01,
#        6.66665500e-01, 2.09677000e-01, 5.94060500e-01, 8.54167000e-01,
#        7.02563500e-01, 9.49273500e-01, 7.44047500e-01, 7.11679000e-01,
#        1.00000000e+00, 3.65079000e-01, 1.26190529e+00, 9.43037000e-01,
#        5.52146000e-01, 3.91305500e-01, 1.01433766e+00, 9.40145500e-01,
#        9.97306000e-01, 8.98655500e-01, 1.00439876e+00, 4.30656000e-01,
#        6.40000000e-01, 7.39877000e-01, 2.64705500e-01, 9.93243000e-01,
#        7.21381000e-01, 9.68421000e-01, 7.59999500e-01, 4.84848250e-01,
#        6.96431500e-01, 8.80386000e-01, 3.66119500e-01, 7.57062500e-01,
#        9.91804500e-01, 5.28301000e-01, 1.25713977e+00, 7.21391500e-01,
#        8.95160500e-01, 4.47369000e-01, 1.03472217e+00, 9.35780500e-01,
#        7.88572000e-01, 6.68571500e-01, 9.52098500e-01, 1.30508605e+00,
#        5.16482900e-01, 8.64411000e-01, 8.70588500e-01, 8.63949000e-01,
#        7.13414000e-01, 8.83425500e-01, 6.31945500e-01, 1.25510199e+00,
#        4.93273500e-01, 9.58333000e-01, 6.21620500e-01, 3.87283000e-01,
#        1.31521753e+00, 1.08880335e+00, 1.01633246e+00, 1.06308859e+00,
#        9.34663500e-01, 8.81102519e-01, 1.06329135e+00, 3.21168000e-01,
#        4.81751000e-01, 7.86096500e-01, 5.11476400e-01, 3.18840000e-01,
#        7.57574000e-01, 8.71793000e-01, 1.10294016e+00, 8.43136000e-01,
#        8.25001000e-01, 8.44545500e-01, 4.12844000e-01, 7.69231000e-01,
#        8.84955000e-01, 8.31274000e-01, 7.26774000e-01, 2.68292500e-01,
#        8.41462000e-01, 1.02061854e+00, 9.08256500e-01, 7.61904000e-01,
#        1.04629598e+00, 3.66057000e-01, 1.23529612e+00, 3.03867500e-01,
#        1.07407175e+00, 7.08582500e-01, 6.11111000e-01, 1.03521115e+00,
#        1.32600495e+00, 7.76471000e-01, 5.92941500e-01, 6.41025000e-01,
#        9.91736000e-01, 7.58169500e-01, 9.58675000e-01, 7.09679000e-01,
#        7.43903000e-01, 4.25289500e-01, 7.43903000e-01, 6.81319500e-01,
#        1.22872463e+00, 1.01433458e+00, 7.65406000e-01, 9.35603000e-01,
#        7.82820500e-01, 9.78990000e-01, 1.00560170e+00, 8.81872500e-01,
#        4.37502000e-01, 1.04151044e+00, 2.35849000e-01, 6.63267000e-01,
#        3.28359000e-01, 7.67122000e-01, 1.06024020e+00, 5.87350500e-01,
#        8.33333500e-01, 1.01064002e+00, 6.47541500e-01, 7.67442000e-01,
#        1.08470870e+00, 8.10605000e-01, 6.65730000e-01, 4.28134500e-01,
#        8.99999500e-01, 1.46914070e+00, 5.58335500e-01, 4.31818000e-01,
#        6.60436000e-01, 7.22688500e-01, 6.10738000e-01, 7.55319500e-01,
#        6.66665500e-01, 8.06200000e-01, 6.71756000e-01, 8.08333500e-01,
#        9.41669500e-01, 8.73238000e-01, 7.74194000e-01, 1.02415364e+00,
#        1.11666715e+00, 7.54166000e-01, 1.14696393e+00, 5.52326000e-01,
#        8.33336500e-01, 4.59647700e-01, 7.36844500e-01, 8.56643000e-01,
#        1.09365097e+00, 2.36956467e-01, 1.01598552e+00, 9.98631277e-01,
#        5.51901874e-01, 5.89431000e-01, 9.34211500e-01, 7.54809000e-01,
#        7.89472500e-01, 5.65574000e-01, 9.88762500e-01, 9.21055500e-01,
#        8.54544500e-01, 6.72130500e-01, 5.46666300e-01, 7.04762500e-01,
#        6.89076000e-01, 7.82892500e-01, 1.03030328e+00, 4.61537800e-01,
#        1.02273000e-01, 6.88523500e-01, 2.37288500e-01, 6.83760000e-01,
#        2.53521500e-01, 9.10568000e-01, 1.43529270e+00, 6.75258000e-01,
#        6.45659500e-01, 6.90265500e-01, 9.27712500e-01, 3.99999500e-01,
#        6.60315500e-01, 6.51687000e-01, 6.81081000e-01, 6.78789000e-01,
#        8.84618000e-01, 3.72058500e-01, 1.41496252e+00, 7.51880000e-01,
#        8.09859000e-01, 1.27710822e+00, 6.15941500e-01, 4.55284000e-01,
#        9.91592500e-01, 5.45454300e-01, 7.66357000e-01, 1.15662896e+00,
#        9.00767500e-01, 1.01377569e+00, 9.17665000e-01, 9.26107000e-01,
#        9.15310500e-01, 1.00195030e+00, 9.58288000e-01, 4.27967000e-01,
#        1.29950716e+00, 6.59420000e-01, 7.04663000e-01, 6.97529500e-01,
#        7.20207000e-01, 9.81129000e-01, 6.74284500e-01, 8.53209000e-01,
#        9.61039000e-01, 7.64194500e-01, 5.33900350e-01, 5.73169500e-01,
#        7.37255000e-01, 1.66666500e-01, 2.28571000e-01, 7.50000000e-01,
#        7.30770000e-01, 5.94870500e-01, 1.25287456e+00, 8.34436000e-01])

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
clfX = XGBClassifiermodel = XGBClassifier(silent=False, 
                      n_estimators=1008, 
                      reg_alpha = 0.38,
                      max_depth=3, 
                      gamma=0.88)

# %%
accuracy= cross_val_score(clfX,X_train,y_train,cv=5)
accuracy.mean()
# Out:
# 0.812285812333282

# %%
clfX.fit(x_train_norm,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.88,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=1008, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0.38, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=False, subsample=1, verbosity=1)

# %%
y_predict =clfX.predict(x_val_norm)
sum(y_predict == y_val)/len(y_val)
# Out:
# 0.810479375696767
